# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Checking Dataset Features

# %%
import pandas as pd

df = pd.read_csv("all_agent_data_filtered_external_False_constant_True_outliers_False.csv")
df.head(10)
# Out:
#    cpuUser  block:block_bio_remap  block:block_getrq  block:block_unplug  \
# 0      1.4                     12                  4                   2
# 1      1.8                     13                  8                   3
# 2      2.7                      6                  2                   1
# 3      3.8                      6                  2                   1
# 4      3.2                      6                  2                   1
# 5      1.9                      6                  2                   1
# 6      3.4                      7                  3                   2
# 7      2.9                      4                  4                   1
# 8      1.8                      7                  3                   2
# 9      3.0                      9                  4                   2
#
#    fib:fib_table_lookup  filemap:mm_filemap_add_to_page_cache  \
# 0                     6                                     1
# ...

# %%
print(len(df.columns))
print(df.columns)
# Out:
# 48
# Index(['cpuUser', 'block:block_bio_remap', 'block:block_getrq',
#        'block:block_unplug', 'fib:fib_table_lookup',
#        'filemap:mm_filemap_add_to_page_cache', 'gpio:gpio_value',
#        'ipi:ipi_raise', 'jbd2:jbd2_handle_start', 'kmem:kfree', 'kmem:kmalloc',
#        'kmem:mm_page_alloc_zone_locked', 'kmem:mm_page_pcpu_drain',
#        'mmc:mmc_request_start', 'net:net_dev_queue', 'net:net_dev_xmit',
#        'net:netif_rx', 'page-faults', 'pagemap:mm_lru_insertion',
#        'qdisc:qdisc_dequeue', 'random:get_random_bytes',
#        'random:mix_pool_bytes_nolock', 'rpm:rpm_resume', 'rpm:rpm_suspend',
#        'sched:sched_process_exec', 'sched:sched_process_free',
#        'sched:sched_process_wait', 'signal:signal_deliver',
#        'signal:signal_generate', 'skb:kfree_skb',
#        'skb:skb_copy_datagram_iovec', 'task:task_newtask',
#        'tcp:tcp_destroy_sock', 'tcp:tcp_probe', 'timer:timer_start',
#        'workqueue:workqueue_activate_work',
# ...

# %%
import pandas as pd

df = pd.read_csv("all_agent_data_filtered_external_False_constant_True_outliers_True.csv")
df.head(10)
# Out:
#     cpuUser  block:block_bio_remap  block:block_getrq  block:block_unplug  \
# 81      2.5                      6                  2                   1
# 84      2.2                      8                  2                   1
# 85      2.9                      6                  2                   1
# 86      1.7                      6                  2                   1
# 88      2.4                      6                  2                   1
# 89      2.7                      8                  2                   1
# 92      2.8                      6                  2                   1
# 94     14.8                      6                  2                   1
# 95      1.8                      6                  2                   1
# 97      7.7                      6                  2                   1
#
#     fib:fib_table_lookup  filemap:mm_filemap_add_to_page_cache  \
# 81                     6                                     1
# ...

# %%
print(len(df.columns))
print(df.columns)
# Out:
# 48
# Index(['cpuUser', 'block:block_bio_remap', 'block:block_getrq',
#        'block:block_unplug', 'fib:fib_table_lookup',
#        'filemap:mm_filemap_add_to_page_cache', 'gpio:gpio_value',
#        'ipi:ipi_raise', 'jbd2:jbd2_handle_start', 'kmem:kfree', 'kmem:kmalloc',
#        'kmem:mm_page_alloc_zone_locked', 'kmem:mm_page_pcpu_drain',
#        'mmc:mmc_request_start', 'net:net_dev_queue', 'net:net_dev_xmit',
#        'net:netif_rx', 'page-faults', 'pagemap:mm_lru_insertion',
#        'qdisc:qdisc_dequeue', 'random:get_random_bytes',
#        'random:mix_pool_bytes_nolock', 'rpm:rpm_resume', 'rpm:rpm_suspend',
#        'sched:sched_process_exec', 'sched:sched_process_free',
#        'sched:sched_process_wait', 'signal:signal_deliver',
#        'signal:signal_generate', 'skb:kfree_skb',
#        'skb:skb_copy_datagram_iovec', 'task:task_newtask',
#        'tcp:tcp_destroy_sock', 'tcp:tcp_probe', 'timer:timer_start',
#        'workqueue:workqueue_activate_work',
# ...

# %% [markdown]
# ## 1. afterstates_online_agent

# %%
# import required module
import os
 
# assign directory
directory = 'afterstates_online_agent'
 
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        df = pd.read_csv(filename.path)
        print("{0} ({1}) => {2}".format(filename.name, len(df.columns), df.columns))
# Out:
# ransom_as_removerk_noexpfs_online_samples_2_2022-08-16-19-06_5s.csv (100) => Index(['time', 'timestamp', 'seconds', 'connectivity', 'cpuUser', 'cpuSystem',
#        'cpuNice', 'cpuIdle', 'cpuIowait', 'cpuHardIrq', 'cpuSoftIrq', 'tasks',
#        'tasksRunning', 'tasksSleeping', 'tasksStopped', 'tasksZombie',
#        'ramFree', 'ramUsed', 'ramCache', 'memAvail', 'iface0RX', 'iface0TX',
#        'iface1RX', 'iface1TX', 'numEncrypted', 'alarmtimer:alarmtimer_fired',
#        'alarmtimer:alarmtimer_start', 'block:block_bio_backmerge',
#        'block:block_bio_remap', 'block:block_dirty_buffer',
#        'block:block_getrq', 'block:block_touch_buffer', 'block:block_unplug',
#        'cachefiles:cachefiles_create', 'cachefiles:cachefiles_lookup',
#        'cachefiles:cachefiles_mark_active', 'clk:clk_set_rate',
#        'cpu-migrations', 'cs', 'dma_fence:dma_fence_init',
#        'fib:fib_table_lookup', 'filemap:mm_filemap_add_to_page_cache',
# ...

# %%
pd.read_csv("afterstates_online_agent/ransom_as_removerk_noexpfs_online_samples_2_2022-08-16-19-06_5s.csv");

# %% [markdown]
# ## 2. decision_states_online_agent

# %%
# import required module
import os
 
# assign directory
directory = 'decision_states_online_agent'
 
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        df = pd.read_csv(filename.path)
        print("{0} ({1}) => {2}".format(filename.name, len(df.columns), df.columns))
# Out:
# cnc_thetick_online_samples_1_2022-09-12-10-27_5s.csv (100) => Index(['time', 'timestamp', 'seconds', 'connectivity', 'cpuUser', 'cpuSystem',
#        'cpuNice', 'cpuIdle', 'cpuIowait', 'cpuHardIrq', 'cpuSoftIrq', 'tasks',
#        'tasksRunning', 'tasksSleeping', 'tasksStopped', 'tasksZombie',
#        'ramFree', 'ramUsed', 'ramCache', 'memAvail', 'iface0RX', 'iface0TX',
#        'iface1RX', 'iface1TX', 'numEncrypted', 'alarmtimer:alarmtimer_fired',
#        'alarmtimer:alarmtimer_start', 'block:block_bio_backmerge',
#        'block:block_bio_remap', 'block:block_dirty_buffer',
#        'block:block_getrq', 'block:block_touch_buffer', 'block:block_unplug',
#        'cachefiles:cachefiles_create', 'cachefiles:cachefiles_lookup',
#        'cachefiles:cachefiles_mark_active', 'clk:clk_set_rate',
#        'cpu-migrations', 'cs', 'dma_fence:dma_fence_init',
#        'fib:fib_table_lookup', 'filemap:mm_filemap_add_to_page_cache',
# ...

# %% [markdown]
# ## 3. raw_behaviors_no_agent_rp3

# %%
# import required module
import os
 
# assign directory
directory = 'raw_behaviors_no_agent_rp3'
 
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        df = pd.read_csv(filename.path)
        print("{0} ({1}) => {2}".format(filename.name, len(df.columns), df.columns))
# Out:
# ransom_expfs_online_samples_1_2022-08-22-14-04_5s.csv (100) => Index(['time', 'timestamp', 'seconds', 'connectivity', 'cpuUser', 'cpuSystem',
#        'cpuNice', 'cpuIdle', 'cpuIowait', 'cpuHardIrq', 'cpuSoftIrq', 'tasks',
#        'tasksRunning', 'tasksSleeping', 'tasksStopped', 'tasksZombie',
#        'ramFree', 'ramUsed', 'ramCache', 'memAvail', 'iface0RX', 'iface0TX',
#        'iface1RX', 'iface1TX', 'numEncrypted', 'alarmtimer:alarmtimer_fired',
#        'alarmtimer:alarmtimer_start', 'block:block_bio_backmerge',
#        'block:block_bio_remap', 'block:block_dirty_buffer',
#        'block:block_getrq', 'block:block_touch_buffer', 'block:block_unplug',
#        'cachefiles:cachefiles_create', 'cachefiles:cachefiles_lookup',
#        'cachefiles:cachefiles_mark_active', 'clk:clk_set_rate',
#        'cpu-migrations', 'cs', 'dma_fence:dma_fence_init',
#        'fib:fib_table_lookup', 'filemap:mm_filemap_add_to_page_cache',
# ...

# %% [markdown]
# ## 4. raw_behaviors_no_agent_rp4

# %%
# import required module
import os
 
# assign directory
directory = 'raw_behaviors_no_agent_rp4'
 
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        df = pd.read_csv(filename.path)
        print("{0} ({1}) => {2}".format(filename.name, len(df.columns), df.columns))
# Out:
# normal_samples_2022-06-10-09-25_50s.csv (100) => Index(['time', 'timestamp', 'seconds', 'connectivity', 'cpuUser', 'cpuSystem',
#        'cpuNice', 'cpuIdle', 'cpuIowait', 'cpuHardIrq', 'cpuSoftIrq', 'tasks',
#        'tasksRunning', 'tasksSleeping', 'tasksStopped', 'tasksZombie',
#        'ramFree', 'ramUsed', 'ramCache', 'memAvail', 'iface0RX', 'iface0TX',
#        'iface1RX', 'iface1TX', 'numEncrypted', 'alarmtimer:alarmtimer_fired',
#        'alarmtimer:alarmtimer_start', 'block:block_bio_backmerge',
#        'block:block_bio_remap', 'block:block_dirty_buffer',
#        'block:block_getrq', 'block:block_touch_buffer', 'block:block_unplug',
#        'cachefiles:cachefiles_create', 'cachefiles:cachefiles_lookup',
#        'cachefiles:cachefiles_mark_active', 'clk:clk_set_rate',
#        'cpu-migrations', 'cs', 'dma_fence:dma_fence_init',
#        'fib:fib_table_lookup', 'filemap:mm_filemap_add_to_page_cache',
#        'gpio:gpio_value', 'ipi:ipi_raise', 'irq:irq_handler_entry',
# ...
